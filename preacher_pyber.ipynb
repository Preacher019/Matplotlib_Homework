# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_df = pd.read_csv("C:/Users/Matt/Pictures/Matplotlib Homework Instructions/Pyber/data/city_data.csv")
ride_df = pd.read_csv("C:/Users/Matt/Pictures/Matplotlib Homework Instructions/Pyber/data/ride_data.csv")

# Combine the data into a single dataset

combined_data = pd.merge(city_df, ride_df, on="city")
combined_data = combined_data.rename(columns={"city":"City", "driver_count":"Driver Count", "type":"Type", "date":"Date", "fare":"Fare", "ride_id":"Ride ID"})

# Display the data table for preview
combined_data
# Out:
#                  City  Driver Count   Type                 Date   Fare  \
# 0         Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1         Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2         Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3         Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4         Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 5         Richardfort            38  Urban  2018-04-21 03:44:04   9.54
# 6         Richardfort            38  Urban  2018-02-03 00:14:26  29.04
# 7         Richardfort            38  Urban  2018-02-08 15:50:12  16.55
# 8         Richardfort            38  Urban  2018-04-03 15:07:34  40.77
# 9         Richardfort            38  Urban  2018-02-19 14:09:20  27.11
# 10        Richardfort            38  Urban  2018-04-22 03:06:56  39.74
# 11        Richardfort            38  Urban  2018-01-31 14:51:01  43.92
# ...

# %%
total_rides = combined_data["City"].value_counts()
total_rides
# Out:
# West Angela             39
# South Karenland         38
# North Jason             35
# Port Frank              33
# Liumouth                33
# South Evanton           31
# South Phillip           31
# South Michelleport      31
# West Robert             31
# Justinberg              30
# North Jasmine           30
# New Kimberlyborough     30
# West Anthony            30
# Royland                 30
# East Kaylahaven         29
# Loganberg               28
# Richardfort             28
# Karenside               28
# Hurleymouth             28
# West Heidi              28
# Carriemouth             27
# Christopherfurt         27
# Josephside              27
# East Marymouth          27
# Lake Danielberg         26
# West Josephberg         26
# West Christopherberg    26
# Lake Robertside         25
# Grahamburgh             25
# West Samuelburgh        25
#                         ..
# Lake Omar               14
# North Markport          14
# Williamsonville         14
# ...

# %%
urban = combined_data["Type"].value_counts()
urban
# Out:
# Urban       1625
# Suburban     625
# Rural        125
# Name: Type, dtype: int64

# %%
type_and_fare = combined_data[["Type", "Fare"]]
type_and_fare.head()
# Out:
#     Type   Fare
# 0  Urban  13.93
# 1  Urban  14.00
# 2  Urban  17.92
# 3  Urban  10.26
# 4  Urban  23.00

# %%
type_and_fare.plot(kind='bar', figsize=(20,3))
plt.tight_layout()

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city type

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
type_group = combined_data.groupby(['Type,', 'Fare'])
sum_all = type_group.sum()
sum_all

# Build Pie Chart

# Save Figure
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-b11c46205405> in <module>
#       1 # Calculate Type Percents
# ----> 2 type_group = combined_data.groupby(['Type,', 'Fare'])
#       3 sum_all = type_group.sum()
#       4 sum_all.head(10)
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
# ...

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
